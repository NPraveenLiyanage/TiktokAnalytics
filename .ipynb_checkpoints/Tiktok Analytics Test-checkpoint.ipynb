# %% [markdown]
# ## Exploratory analysis

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.3 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.3 MB 3.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.3 MB 3.1 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.3 MB 3.2 MB/s eta 0:00:03
#    --------------- ------------------------ 4.5/11.3 MB 3.5 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.3 MB 3.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.3 MB 3.8 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.3 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.3 MB 4.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
# reading initial json object
df = pd.read_json('export.json')

# %%
#view first 5 object
df.head()
# Out:
#   AIGCDescription  CategoryType  \
# 0                           120
# 1                           101
# 2                           120
# 3                           111
# 4                           100
#
#                                               author  \
# 0  {'UserStoryStatus': 0, 'avatarLarger': 'https:...
# 1  {'UserStoryStatus': 0, 'avatarLarger': 'https:...
# 2  {'UserStoryStatus': 0, 'avatarLarger': 'https:...
# 3  {'UserStoryStatus': 0, 'avatarLarger': 'https:...
# 4  {'UserStoryStatus': 1, 'avatarLarger': 'https:...
#
#                                          authorStats  \
# 0  {'diggCount': 2041, 'followerCount': 4355, 'fo...
# 1  {'diggCount': 680, 'followerCount': 21600, 'fo...
# 2  {'diggCount': 467, 'followerCount': 29700, 'fo...
# 3  {'diggCount': 1573, 'followerCount': 995, 'fol...
# 4  {'diggCount': 1725, 'followerCount': 2200000, ...
#
#                                        authorStatsV2  \
# 0  {'diggCount': '2041', 'followerCount': '4355',...
# ...

# %%
df.to_csv('tiktokData.csv')

# %% [markdown]
# ## Create Helper function to process data

# %%
import json

# %%
#load up data
with open('export.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'AIGCDescription': '',
#   'CategoryType': 120,
#   'author': {'UserStoryStatus': 0,
#    'avatarLarger': 'https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/102212d412aa6aa8c8c99fb1cd87f19d~tplv-tiktokx-cropcenter:1080:1080.jpeg?dr=14579&refresh_token=5b504c62&x-expires=1753002000&x-signature=%2BaW7tRoMcTB1VMLPnQEj%2FKRWPZY%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=my',
#    'avatarMedium': 'https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/102212d412aa6aa8c8c99fb1cd87f19d~tplv-tiktokx-cropcenter:720:720.jpeg?dr=14579&refresh_token=8a758ff9&x-expires=1753002000&x-signature=7VzeVj0SdgxSpMCexBN0e9fXpMk%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=my',
#    'avatarThumb': 'https://p16-sign-sg.tiktokcdn.com/tos-alisg-avt-0068/102212d412aa6aa8c8c99fb1cd87f19d~tplv-tiktokx-cropcenter:100:100.jpeg?dr=14579&refresh_token=8ffffb76&x-expires=1753002000&x-signature=QqDcENfeikW1Wea6BrJyQX3dUY8%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=my',
# ...

# %%
nested_values = ['author', 'authorStats', 'authorStatsV2', 'music','video','stats', 'statsV2']
skip_values = ['challenges', 'backendSourceEventTracking', 'contents',
              'item_control', 'textExtra', 'videoSuggestWordsList']
